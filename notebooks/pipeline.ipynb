# %%
import sys
import pandas as pd
sys.path.append('../scripts/')
from extraction_pipeline import ExtractionPipeline

# %%
from load_data import Loader
loader = Loader()
bucket = "s3://10ac-batch-6/data/w11/Challenge_Data.zip"
file_path = "Challenge_Data/performance_data.csv"
df = loader.load_csv(bucket,file_path)

# %%
# for test, we will work on only 2 col df

tst = df.sample(3)
extractor = ExtractionPipeline(df=tst)
extractor.extract_features()
# Out:
# 2022-11-05 21:14:54.943876: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-11-05 21:14:55.121971: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2799995000 Hz
# 0                                            game_id  \
# 0                   55775796ac3c2a0fd0fde4cae6048827
# 1        adunit-jaguar-nameplate-refresh-v2-mfcc-mob
# 2  adunit-chevy-user-slider-seat-interior-300-600...
#
# 0                                     preview_link_x                ER_x  \
# 0  https://s3.us-west-1.amazonaws.com/a.futureadl...  0.0273660557198328
# 1  https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.0853256966703448
# 2  https://s3.us-east-1.amazonaws.com/a.futureadl...  0.0241522227853995
#
# 0               CTR_x                                           all_text  \
# 0  0.0031576218138268  [ea, BUY TICKETS NOW, ONLY IN THEATERS JUNE 16...
# 1  0.0066207766276075  [NEW JAGUAR, E-PACE, Ls, 106 TCH, | jee, qiing...
# 2   0.001564231719709  [CHEVROLET, ALL-ELECTRIC, ee, 12, eam lei mele...
#
# 0                                     preview_link_y                ER_y  \
# 0  https://s3.us-west-1.amazonaws.com/a.futureadl...  0.0273660557198328
# 1  https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.0853256966703448
# 2  https://s3.us-east-1.amazonaws.com/a.futureadl...  0.0241522227853995
#
# 0               CTR_y                                        all_objects  \
# 0  0.0031576218138268  [person, person, person, person, tie, cell pho...
# 1  0.0066207766276075  [car, car, car, car, car, car, car, car, car, ...
# 2   0.001564231719709  [mouse, clock, clock, car, cell phone, person,...
#
# 0  all_objects_count  unique_objects_count                file_name  \
# 0                 55                     6  [logo.png, f2-logo.png]
# 1                 96                     6                      NaN
# 2                 15                     6               [logo.png]
#
# 0       shape top_left bottom_right      LAR
# 0  (900, 600)  (89, 6)   (511, 202)  0.15317
# 1         NaN      NaN          NaN      NaN
# 2      (0, 0)   (0, 0)       (0, 0)  0.00000
